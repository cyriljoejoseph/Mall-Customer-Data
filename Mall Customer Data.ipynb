# %%
import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mall= pd.read_csv("mall customers.csv")
mall.head()
# Out:
#    Unnamed: 0  CustomerID  Gender  Age  Annual.Income..k..  \
# 0           1           1    Male   19                  15
# 1           2           2    Male   21                  15
# 2           3           3  Female   20                  16
# 3           4           4  Female   23                  16
# 4           5           5  Female   31                  17
#
#    Spending.Score..1.100.  segments
# 0                      39         3
# 1                      81         2
# 2                       6         3
# 3                      77         2
# 4                      40         3

# %%
mall = mall.rename(index=str, columns={
    'Annual.Income..k..': 'Income',
    'Spending.Score..1.100.': 'SpendingScore'
})

# %% [markdown]
# x= mall.Annual.income
# y= age
# plt.figure()
# plt.scatter(x,y)

# %%
mall= mall.drop(columns=['Unnamed: 0','CustomerID'])
mall.head()
# Out:
#    Gender  Age  Income  SpendingScore  segments
# 0    Male   19      15             39         3
# 1    Male   21      15             81         2
# 2  Female   20      16              6         3
# 3  Female   23      16             77         2
# 4  Female   31      17             40         3

# %%
len(mall)
# Out:
# 200

# %%
mall.groupby('Gender').size().plot(kind='pie', autopct='%.2f',ylabel='Gender')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
sns.barplot(data=mall, x='Gender', y='SpendingScore',hue='Gender');
plt.legend(loc="upper center")

# %%
x= mall["SpendingScore"]
y= mall.Age 
plt.figure() 
plt.scatter(x,y)

# %%
scatter= mall.plot.scatter(x='SpendingScore',
                           y='Income',
                           c='Age', 
                           colormap='viridis')

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(data=mall, x='SpendingScore',y='Income', hue='Gender');
